# %%
boxplot(mpg ~ cyl, data=mtcars,xlab="Number of Cylinders",ylab="Miles Per Gallon",
main="Mileage Data",notch=F,col=c("green","yellow","purple"),names=c("High","Medium","Low"))
# Out:
# Plot with title “Mileage Data”

# %%
x = c(1:10)
y = x^2
z=x^3
matplot(x,cbind(y,z),pch=c(16,1))
# Out:
# plot without title

# %%
hist(AirPassengers,main="Histogram for Air Passengers",xlab="Passengers",
border="red",col="blue",xlim=c(100,700),breaks=5)
# Out:
# Plot with title “Histogram for Air Passengers”

# %%
plot(c(56,67,78),main="Rainfall",col="Red", type="o", ylim=c(1,100), xlim=c(1,3))
lines(c(34,67,87),type="o",col="Blue")
# Out:
# Plot with title “Rainfall”

# %%
pairs(cyl~wt,data=mtcars,main="Scatterplot Matrix")
# Out:
# plot without title

# %%
mosaicplot(UCBAdmissions, sort = 3:1,
col = hcl(c(120, 10)),
main = "Student admissions at UC Berkeley")
# Out:
# Plot with title “Student admissions at UC Berkeley”

# %%
dotchart(c(12,23,34,45,45),xlab="v",ylab="er")
# Out:
# plot without title

# %%
qqplot(trees$Volume,trees$Girth, main="Volume vs Girth of trees")
# Out:
# Plot with title “Volume vs Girth of trees”

# %%
packages.install("ggplot2")
# Out:
# Error in package.install("ggplot2"): could not find function "package.install"
# Traceback:
