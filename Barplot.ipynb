# %%
h = c(45,56,67,78)
p = c("US","EU","CN","IN")

help(barplot)
barplot(h,main="Happiness index", col="green", border="red",names.arg=p,xlab="Country", ylab="happiness")
# Out:
# Plot with title “Happiness index”
# barplot                package:graphics                R Documentation
#
# s
#
# n:
#
#      Creates a bar plot with vertical or horizontal bars.
#
# e:
#
#      barplot(height, ...)
#
#      ## Default S3 method:
#      barplot(height, width = 1, space = NULL,
#              names.arg = NULL, legend.text = NULL, beside = FALSE,
#              horiz = FALSE, density = NULL, angle = 45,
#              col = NULL, border = par("fg"),
#              main = NULL, sub = NULL, xlab = NULL, ylab = NULL,
#              xlim = NULL, ylim = NULL, xpd = TRUE, log = "",
#              axes = TRUE, axisnames = TRUE,
#              cex.axis = par("cex.axis"), cex.names = par("cex.axis"),
#              inside = TRUE, plot = TRUE, axis.lty = 0, offset = 0,
#              add = FALSE, args.legend = NULL, ...)
#
# s:
#
#   height: either a vector or matrix of values describing the bars which
#           make up the plot.  If ‘height’ is a vector, the plot consists
# ...
