# %%
v = c(70,56,57,98,76)
l = c("Math","Science","Social", "Tamil","English")

pc = paste(l,v)

pie(v,main="Marksheet", labels=pc,col=rainbow(5))
legend("topright",l,fill=rainbow(5))
# Out:
# Plot with title “Marksheet”
